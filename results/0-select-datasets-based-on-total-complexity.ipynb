# %%
import pandas as pd
import glob

# %%
TO_SELECT = 10

# %%
df = pd.read_csv("../results/keel-dataset-complexities.csv", index_col=0)

# %%
df
# Out:
#                       f1        f2        f3        f4       f1v        c1  \
# name
# glass           0.711257  0.151533  0.492212  0.239097  0.231340  0.432478
# abalone         0.952935  0.070588  0.500086  0.443468  0.279092  0.822646
# flare           0.689589  0.000000  0.518918  0.360538  0.272605  0.394104
# wisconsin       0.349593  0.287741  0.938507  0.853587  0.082540  0.065997
# bupa            0.952096  0.750733  0.982609  0.965217  0.731915  0.018411
# ...                  ...       ...       ...       ...       ...       ...
# breast          0.803318  0.600000  0.978339  0.978339  0.478150  0.128175
# crx             0.293771  0.442606  0.969372  0.958652  0.146736  0.006304
# thyroid         0.655479  0.000000  0.076111  0.041898  0.125468  0.723116
# vowel           0.819053  0.222102  0.534343  0.281084  0.290282  0.560503
# post-operative  0.940084  0.333333  0.739464  0.659004  0.535645  0.398141
#
# ...
