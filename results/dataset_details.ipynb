# %%
import pandas as pd
from datasetz.core.load_dataset import load_embedded_dataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 2
#       1 import pandas as pd
# ----> 2 from datasetz.core.load_dataset import load_embedded_dataset
#
# ModuleNotFoundError: No module named 'datasetz'

# %%
DATASETS = ['wisconsin', 'bupa', 'bands', 'ionosphere', 'hepatitis', 'saheart',
            'haberman', 'housevotes', 'heart', 'australian', 'tic-tac-toe',
            'mammographic', 'monk-2', 'appendicitis', 'breast', 'crx']

# %%
for d in DATASETS:
    dataset = load_embedded_dataset('keel-binary-fast', d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 for d in DATASETS:
# ----> 2     dataset = load_embedded_dataset('keel-binary-fast', d)
#
# NameError: name 'load_embedded_dataset' is not defined

# %%
complexities_df = pd.read_csv('complexities.csv')

# %%
time_columns = [c for c in complexities_df.columns if "-time" in c]

# %%
'f2', 't4', 'c1', 'n3', 'l2', 'density'

# %%
complexities_df[time_columns].mean().sort_values()
# Out:
# t2-time          0.000036
# c1-time          0.000088
# c2-time          0.000118
# f2-time          0.000311
# f3-time          0.000431
# f1-time          0.000447
# t4-time          0.001687
# t3-time          0.001695
# f4-time          0.008822
# n2-time          0.009814
# f1v-time         0.013929
# n3-time          0.048440
# l2-time          0.055594
# l1-time          0.055877
# lsc-time         0.078426
# l3-time          0.099713
# n4-time          0.100265
# t1-time          0.319571
# density-time     0.336880
# n1-time          0.583608
# hubs-time        0.672919
# clsCoef-time    11.501390
# dtype: float64

# %%
complexities_df.melt(time_columns)
# Out:
#        f1-time   f2-time   f3-time   f4-time  f1v-time   c1-time   c2-time  \
# 0     0.000333  0.000181  0.000392  0.003115  0.021765  0.000065  0.000073
# 1     0.000266  0.000185  0.000379  0.003853  0.021445  0.000066  0.000072
# 2     0.000249  0.000169  0.000361  0.002671  0.021689  0.000066  0.000069
# 3     0.000252  0.000176  0.000388  0.003753  0.020937  0.000070  0.000072
# 4     0.000221  0.000168  0.000382  0.003247  0.021489  0.000061  0.000075
# ...        ...       ...       ...       ...       ...       ...       ...
# 7245  0.000173  0.000128  0.000224  0.000875  0.006921  0.000055  0.000059
# 7246  0.000179  0.000134  0.000230  0.000479  0.007082  0.000054  0.000059
# 7247  0.000174  0.000129  0.000223  0.000613  0.006941  0.000058  0.000059
# 7248  0.000179  0.000133  0.000216  0.000620  0.007139  0.000057  0.000059
# 7249  0.000175  0.000132  0.000229  0.000341  0.007011  0.000057  0.000066
#
# ...
